# %% [markdown]
# # Observed FCH4 time-series diagnostics for Appendix A
#
# This compact, report-specific notebook replaces the unsuitable all-period diagnostics in `temp_TSA.ipynb`. It uses QC-observed FCH4 only: no target values are generated beyond a tower's observed record.
#
# It writes additive, report-ready candidates for Appendix Figures A.5 and A.6, without editing the report source.

# %% [markdown]
# ## Method
#
# - Hourly ACF uses all available observed pairs at each true lag.
# - Daily PACF and weekly STL use the longest continuous daily segment with at least six observed hours per day; only internal gaps of at most two days are interpolated.
# - This makes the differing support explicit, instead of treating model-generated values in unobserved years as measurements.

# %%
from export_observed_tsa_appendix import main
summary = main()
summary.round(3)
# Out:
# Wrote:
#   results\figures\tsa_observed_diagnostics\tsa_acf_pacf_observed.png
#   results\figures\tsa_observed_diagnostics\tsa_stl_observed_daily.png
#   results\tsa_observed_diagnostics\observed_tsa_summary.csv
#   report\Figures\ch3_acf_pacf_observed.png
#   report\Figures\ch3_stl_decomposition_observed.png
#    tower      first_observed       last_observed  n_observed_hours  \
# 0      2 2017-10-06 12:00:00 2019-05-31 19:00:00              4890
# 1      4 2017-10-06 16:00:00 2023-12-31 23:00:00             19469
# 2      9 2020-02-04 05:00:00 2023-12-31 23:00:00             11235
#
#   daily_segment_start daily_segment_end  daily_segment_days  pacf_lag_1_day  \
# 0          2018-09-26        2019-02-15                 143           0.363
# 1          2022-02-24        2022-10-20                 239           0.698
# 2          2023-05-31        2023-12-24                 208           0.407
#
#    pacf_lag_7_days  acf_lag_1_hours  n_pairs_lag_1_hours  acf_lag_6_hours  \
# ...
