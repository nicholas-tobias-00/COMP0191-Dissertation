# %%
import pandas as pd

# %%
filepath = 'Dataset/Consolidated/measurements_2017-01-01_2018-01-01.csv'

df = pd.read_csv(filepath)

# %%
df.head(5)
# Out:
#               Datetime  Flow (l/s) [Catchment 1]  \
# 0  2017/01/01 00:15:00                    0.1414
# 1  2017/01/01 00:30:00                    0.1414
# 2  2017/01/01 00:45:00                    0.1414
# 3  2017/01/01 01:00:00                    0.1414
# 4  2017/01/01 01:15:00                    0.1414
#
#   Flow (l/s) [Catchment 1] Quality  \
# 0                       Acceptable
# 1                       Acceptable
# 2                       Acceptable
# 3                       Acceptable
# 4                       Acceptable
#
#   Flow (l/s) [Catchment 1] Quality Last Modified  Flow (l/s) [Catchment 2]  \
# 0                                     2018/11/24                       NaN
# 1                                     2018/11/24                       NaN
# 2                                     2018/11/24                       NaN
# 3                                     2018/11/24                       NaN
# ...

# %%
filepath = 'Dataset/Consolidated/greenhouse_2017-01-01_2018-01-01.csv'

df = pd.read_csv(filepath)

# %%
df.head(5)
# Out:
#               Datetime  CO2_1_1_1 [Tower 2]  H2O_1_1_1 [Tower 2]  \
# 0  2017/01/01 00:30:00           373.002829             2.582062
# 1  2017/01/01 01:00:00           371.852183             2.612844
# 2  2017/01/01 01:30:00           370.031688             2.637917
# 3  2017/01/01 02:00:00           370.166670             2.715083
# 4  2017/01/01 02:30:00           372.749172             2.548190
#
#    CH4_1_1_1 [Tower 2]  TAU_1_1_1 [Tower 2]  TAU_SSITC_TEST_1_1_1 [Tower 2]  \
# 0                  NaN             0.069802                             0.0
# 1                  NaN             0.113796                             0.0
# 2                  NaN             0.100904                             0.0
# 3                  NaN             0.076227                             0.0
# 4                  NaN             0.110068                             0.0
#
#    H_1_1_1 [Tower 2]  H_SSITC_TEST_1_1_1 [Tower 2]  LE_1_1_1 [Tower 2]  \
# ...
